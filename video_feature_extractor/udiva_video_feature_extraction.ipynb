# %% [markdown]
# # Inference

# %%
# !pip install pytorchvideo
# Out:
# ...
#      |████████████████████████████████| 128 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 49 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 37.2 MB 30 kB/s
# ...
#      |████████████████████████████████| 636 kB 36.1 MB/s
# ...
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.3-py3-none-any.whl size=183829 sha256=14e1fcaec64f123aabaa62a4d2eb135d94b7271f2b6655cd6aafa2faf6bc69a2
#   Stored in directory: /root/.cache/pip/wheels/d4/a7/4c/bada8b1065ae9befac2da6d7f6648cd6718681eb7901ca226d
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20210924-py3-none-any.whl size=60829 sha256=0e946e834c701db28410d91b38b52c523613c040a60708c519cb85f6390a5b5f
#   Stored in directory: /root/.cache/pip/wheels/70/c6/de/aa41c65141bdbc9a8aa4b303ce26482aa2f1720ff41b7f17c3
# Successfully built pytorchvideo fvcore
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !mkdir output && mkdir data && mkdir video_feature_extractor
# %cd data
# !wget https://dl.fbaipublicfiles.com/pytorchvideo/projects/archery.mp4 
# %cd /content
# Out:
# /content/data
# --2021-09-29 14:46:22--  https://dl.fbaipublicfiles.com/pytorchvideo/projects/archery.mp4
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 172.67.9.4, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 549197 (536K) [video/mp4]
# Saving to: ‘archery.mp4’
#
# archery.mp4         100%[===================>] 536.33K  1.62MB/s    in 0.3s
#
# 2021-09-29 14:46:23 (1.62 MB/s) - ‘archery.mp4’ saved [549197/549197]
#
# /content

# %%
# !gsutil cp -r gs://udiva-iiitb/data/train/videos/172185 /content/data
# Out:
# ServiceException: 401 Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object.

# %%
# !python inference.py --device cpu --model x3d_s --source /content/data/172185
# Out:
# [Errno 2] No such file or directory: 'video_feature_extractor'
# /content/video_feature_extractor
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The _functional_video module is deprecated. Please use the functional module instead.
#   "The _functional_video module is deprecated. Please use the functional module instead."
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/_transforms_video.py:26: UserWarning: The _transforms_video module is deprecated. Please use the transforms module instead.
#   "The _transforms_video module is deprecated. Please use the transforms module instead."
# Namespace(device='cpu', do_split=False, model_name='x3d_s', output='../output', source='/content/data/172185')
# Traceback (most recent call last):
#   File "inference.py", line 106, in <module>
#     inference(opt)
#   File "inference.py", line 79, in inference
#     model = VideoFeatureExtractor(model_name, device=device)
# ...

# %% [markdown]
# # Video feature extraction

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !curl https://sdk.cloud.google.com | bash

# %%
# !gcloud init

# %%
# !echo "deb http://packages.cloud.google.com/apt gcsfuse-bionic main" > /etc/apt/sources.list.d/gcsfuse.list
# !curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | apt-key add -
# !apt -qq update
# !apt -qq install gcsfuse

# %%
# !mkdir folderOnColab
# !gcsfuse folderOnBucket/content/ folderOnColab

# %%
# !gsutil ls gs://udiva-iiitb/data/train/videos/udiva/076122/
# !gsutil ls gs://udiva-iiitb/data/train/videos/udiva >> videos.txt

# %%
# !mkdir input
# !mkdir output
# !mkdir video_feature_extractor
# !gsutil cp -r gs://udiva-iiitb/data/train/videos/172185/ ./input
# !bash download_videos.sh
# Out:
# Copying gs://udiva-iiitb/data/train/videos/udiva/144171/FC1_T.mp4...
# Copying gs://udiva-iiitb/data/train/videos/udiva/144171/FC2_T.mp4...
# / [2 files][279.1 MiB/279.1 MiB]   28.6 MiB/s
# Operation completed over 2 objects/279.1 MiB.
# Copying gs://udiva-iiitb/data/train/videos/udiva/144176/FC1_T.mp4...
# Copying gs://udiva-iiitb/data/train/videos/udiva/144176/FC2_T.mp4...
# \ [2 files][250.6 MiB/250.6 MiB]   33.2 MiB/s
# Operation completed over 2 objects/250.6 MiB.
# Copying gs://udiva-iiitb/data/train/videos/udiva/148151/FC1_T.mp4...
# Copying gs://udiva-iiitb/data/train/videos/udiva/148151/FC2_T.mp4...
# | [2 files][351.5 MiB/351.5 MiB]   38.8 MiB/s
# Operation completed over 2 objects/351.5 MiB.
# Copying gs://udiva-iiitb/data/train/videos/udiva/151164/FC1_T.mp4...
# Copying gs://udiva-iiitb/data/train/videos/udiva/151164/FC2_T.mp4...
# / [2 files][302.4 MiB/302.4 MiB]   11.0 MiB/s
# Operation completed over 2 objects/302.4 MiB.
# ...

# %%
try:
    import torch
except ModuleNotFoundError:
    # !pip install torch torchvision
    import os
    import sys
    import torch
    
if torch.__version__=='1.6.0+cu101' and sys.platform.startswith('linux'):
    print('hello')
    # !pip install pytorchvideo
else:
    need_pytorchvideo=False
    try:
        # Running notebook locally
        import pytorchvideo
    except ModuleNotFoundError:
        need_pytorchvideo=True
    if need_pytorchvideo:
        # Install from GitHub
        # !pip install "git+https://github.com/facebookresearch/pytorchvideo.git"
# Out:
# ...
#   Cloning https://github.com/facebookresearch/pytorchvideo.git to /tmp/pip-req-build-j_16ybn7
#   Running command git clone -q https://github.com/facebookresearch/pytorchvideo.git /tmp/pip-req-build-j_16ybn7
# ...
#      |████████████████████████████████| 49 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 37.2 MB 29 kB/s
# ...
#      |████████████████████████████████| 636 kB 49.7 MB/s
# ...
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.3-py3-none-any.whl size=183829 sha256=2b98e0ca02067b11944413ab29d6340adfe2433b69608f8c628e5b46e1431b86
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_a77xkab/wheels/87/af/3d/0f80973f39ae2239c1ee9496b333ef4e90bf2d80d486b50eca
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20210825-py3-none-any.whl size=60661 sha256=ea447b9683e172c6852e3f6428c556b18d1bc27b7750ffe90b0fbb83f5c64223
#   Stored in directory: /root/.cache/pip/wheels/53/c4/f8/c4cb07f135845218b019b4a55d8a0470a0f21ee13f8dcd16be
# Successfully built pytorchvideo fvcore
# ...

# %%
# !git clone https://github.com/vemshari27/udiva-data.git

# %%
# %cd video_feature_extractor/
# Out:
# /content/video_feature_extractor

# %%
# !python inference.py --device cuda:0 --source ../input --output /content/drive/MyDrive/udiva --do_split
# !python inference.py --device cuda:0 --source ../input --output ../output --do_split
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The _functional_video module is deprecated. Please use the functional module instead.
#   "The _functional_video module is deprecated. Please use the functional module instead."
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/_transforms_video.py:26: UserWarning: The _transforms_video module is deprecated. Please use the transforms module instead.
#   "The _transforms_video module is deprecated. Please use the transforms module instead."
# Namespace(device='cuda:0', do_split=True, model_name='slowfast_r50', output='/content/drive/MyDrive/udiva', source='../input')
# Downloading: "https://github.com/facebookresearch/pytorchvideo/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://dl.fbaipublicfiles.com/pytorchvideo/model_zoo/kinetics/SLOWFAST_8x8_R50.pyth" to /root/.cache/torch/hub/checkpoints/SLOWFAST_8x8_R50.pyth
# ...

# %%
gfhgfh
